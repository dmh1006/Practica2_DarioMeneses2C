# %% [markdown]
# # Práctica 2 – Búsqueda en espacios de estados
# ## Planificación de rutas hospitalarias
#
# Asignatura: Sistemas Inteligentes aplicados en Salud
# Autor: Darío Meneses
#
# Notebook de ejecución y comparación de algoritmos de búsqueda sobre el mapa del hospital.

# %% [markdown]
# ## Objetivo
# Implementar y comparar distintos algoritmos de búsqueda (Anchura, Voraz y A*) para planificar rutas en un mapa de hospital.
#
# Se resuelven dos ejercicios:
# 1. Ruta desde el pasillo más cercano a `D22` hasta el pasillo más cercano a `D1`.
# 2. Ruta por tramos para que el responsable de seguridad pase por las puertas de varios servicios en un orden prefijado, partiendo de una puerta principal.
