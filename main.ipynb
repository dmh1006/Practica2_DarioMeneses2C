# %%
from utils.clases.ProblemaRuta import ProblemaRuta
from utils.algoritmos.anchura import busqueda_anchura
from utils.algoritmos.a_estrella import busqueda_a_estrella
from utils.algoritmos.voraz import busqueda_voraz

# Mapa 3x3 muy simple
mapa = [
    ["P", "P", "P"],
    ["P", "M", "P"],
    ["P", "P", "P"]
]

penalizaciones = {
    "P": 1,
    "M": 999
}

inicio = (0, 0)
objetivo = (2, 2)

problema = ProblemaRuta(inicio, objetivo, mapa, penalizaciones)

res_bfs = busqueda_anchura(problema)
res_astar = busqueda_a_estrella(problema)
res_voraz = busqueda_voraz(problema)

print("ANCHURA:", res_bfs.hay_solucion(), res_bfs.get_coste(), res_bfs.get_camino())
print("A*     :", res_astar.hay_solucion(), res_astar.get_coste(), res_astar.get_camino())
print("VORAZ  :", res_voraz.hay_solucion(), res_voraz.get_coste(), res_voraz.get_camino())
# Out:
# ANCHURA: True 4 [(0, 0), (1, 0), (2, 0), (2, 1), (2, 2)]
# A*     : True 4 [(0, 0), (1, 0), (2, 0), (2, 1), (2, 2)]
# VORAZ  : True 4 [(0, 0), (1, 0), (2, 0), (2, 1), (2, 2)]

# %%
print("Nodos expandidos A*:", res_astar.get_nodos_expandidos())
print("Frontera máx A*:", res_astar.get_frontera_max())
print("Tiempo A* (ms):", res_astar.get_tiempo_ms())
# Out:
# Nodos expandidos A*: 8
# Frontera máx A*: 2
# Tiempo A* (ms): 0.05459785461425781

# %%
from utils.clases.PlanificadorPorTramos import PlanificadorPorTramos
from utils.algoritmos.a_estrella import busqueda_a_estrella

mapa = [
    ["P", "P", "P", "P"],
    ["P", "M", "M", "P"],
    ["P", "P", "P", "P"],
    ["P", "P", "P", "P"]
]

penalizaciones = {
    "P": 1,
    "M": 999
}

inicio = (0, 0)
objetivos = [(2, 0), (3, 3)]

planificador = PlanificadorPorTramos(mapa, penalizaciones)

resultado = planificador.planificar(
    inicio,
    objetivos,
    busqueda_a_estrella
)

print("Solución:", resultado.hay_solucion())
print("Coste total:", resultado.get_coste())
print("Camino:", resultado.get_camino())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils.clases.PlanificadorPorTramos import PlanificadorPorTramos
#       2 from utils.algoritmos.a_estrella import busqueda_a_estrella
#       4 mapa = [
#       5     ["P", "P", "P", "P"],
#       6     ["P", "M", "M", "P"],
#       7     ["P", "P", "P", "P"],
#       8     ["P", "P", "P", "P"]
#       9 ]
#
# ImportError: cannot import name 'PlanificadorPorTramos' from 'utils.clases.PlanificadorPorTramos' (c:\Users\dario\Desktop\UNIVERSIDAD\Ingenieria de la salud- UBU\Quinto curso\Sistemas\Practica2_DarioMeneses2C\utils\clases\PlanificadorPorTramos.py)
