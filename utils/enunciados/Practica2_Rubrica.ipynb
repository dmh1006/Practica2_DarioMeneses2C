# %% [markdown]
# <img style="float:left" width="30%" src="pics/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="8%" src="pics/PythonLogo.svg">
# <br style="clear:both;">
#
# # SISTEMAS INTELIGENTES APLICADOS A LA SALUD
#
#
#
# <h2 style="display: inline-block; padding: 4mm; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">Práctica II: Planificación de rutas hospitalarias mediante algoritmos de búsqueda</h2>
# <br style="clear:both;">
# <h2 style="display: inline-block; padding: 4mm; background-color: green; line-height: 1.3em; color: white; border-radius: 10px;">Segunda Convocatoria</h2>
# <br style="clear:both;">
# <h2 style="display: inline-block; padding: 4mm; padding-left:; background-color: orange; line-height: 1.3em; color: white; border-radius: 10px;">Requisitos y rúbrica de calificación</h2>
#
# ## Docente
#
#  - **David García García**

# %% [markdown]
# ### IMPORTANTE
# - Emplea la plantilla de repositorio de proyecto proporcionada de acuerdo a las características de la práctica.
# - Solo se evaluará y calificará lo entregado en el repositorio.
# - Todas las funciones implementadas deben estar correctamente documentadas.
#
#
# ## Documentos a entregar
#
# - Repositorio **GitHub** privado compartido con `davgarciagarcia` con los archivos necesarios para comprobar el correcto funcionamiento de los requisitos:
# - En el **buzón de entrega** del aula virtual, se incluirá un documento pdf en el que se aparezca un resumen de lo implementado, un diagrama de clases, el enlace al repositorio privado y un manual de funcionamiento.
#
# <div class="alert alert-warning"> El codigo implementado debe ir correctamente comentado de forma que se entienda perfectamente el motivo del desarrollo de cada función, clase o estructura así como la justificación de su funcionamiento. Se podrá penalizar hasta el <kdb>20%</kdb> de la calificación sino aparece ningún comentario en el código entregado.</div>
#
#
# ### `FUNDAMENTAL`
#
# Comprueba que en el repositorio se encuentra todo correctamente incluido y realiza todos los test necesarios (creación de entorno virtual, instalación de paquetes, ejecución de scripts, configuración de módulos...)
#
# ------------------
#
# ## Fecha de entrega
#
# - La fecha límite para la entrega de los documentos de la Práctica 2 de segunda convocatoria será el **3 de febrero de 2026** a las 14:00h.
# - Todos aquellos archivos que no se entreguen de la manera indicada dentro de los límites temporales establecidos, no se serán evaluados ni calificados.
# - Si no se comparte el repositorio antes de la fecha límite, la calificación será de 0.
# - No se tendrán en cuenta las modificaciones realizadas en el repositorio de GitHub más allá de la fecha y hora límite.
# ------------------
#
# ## 📊 Rúbrica de Evaluación
#
# Para la valoración del código entregado, se realizará una descarga del repositorio proporcionado y se seguirán las instrucciones proporcionadas en el README.md para la creación del entorno virtual y la instalación de los paquetes.
#
# > **Total: 10 puntos (30 % de la calificación final de prácticas)**
#
# | Ítem                                          | **Excelente (100 %)**                                | **Aceptable (70–80 %)**                             | **Insuficiente (≤50 %)**                       | Puntos |
# |-----------------------------------------------|------------------------------------------|----------------------------------------|------------------------------------|--------|
# | **Ejercicio 1: Ruta básica**                  | Ruta correcta, visualización clara, funciones bien estructuradas. | Ruta calculada, pero con código poco modular o sin visualización. | Ruta incompleta o sin explicación. | 2    |
# | **Ejercicio 2: Ruta seguridad**      | Ruta correcta en orden, bien modularizada, comparación incluida. | Ruta funcional pero con deficiencias. | Ruta errónea o sin orden.          | 4    |
# | **Comparativa de algoritmos**                | Se comparan todos algoritmos con análisis y métricas. | Comparación parcial o sin análisis.     | No se realiza comparativa.         | 2.5    |
# | **Informe PDF**                               | Informe completo, capturas, mapas, tablas y análisis detallado. | Informe básico o incompleto.           | Informe ausente o irrelevante.     | 1.5    |
#
# ---
#
#
# <div class="alert alert-danger"> <b>IMPORTANTE: </b> Sino se modularizan las funciones implementadas la calificación final será de <b>0</b></div>
#
# <div class="alert alert-danger"> <b>IMPORTANTE: </b> Si se detecta plagio o copia del trabajo la calificación final de parte de prácticas de la asignatura sera de <b>0</b></div>
#
# <div class="alert alert-danger"> <b>IMPORTANTE: </b> Se podrá penalizar hasta el <kdb>20%</kdb> de la calificación sino aparece ningún comentario en el código entregado.</div>
#
# <div class="alert alert-danger"> <b>IMPORTANTE: </b> Se podrá penalizar hasta el <kdb>30%</kdb> de la calificación si el repositorio no está correctamente configurado.</div>
